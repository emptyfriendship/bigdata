# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

fmri = sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y="signal",
            hue="region", style="event",
           data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
import pandas as pd
mpg = pd.read_csv('mpg.csv')

import seaborn as sns

sns.scatterplot(data=mpg, x='displ', y='hwy')\
    .set(xlim = (3, 6))
# Out:
# [(3.0, 6.0)]

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy')\
    .set(xlim = (3, 6), ylim = (10, 30))
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue = 'drv')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %% [markdown]
# # Lab 2 : 혼자서 해보기

# %%
sns.scatterplot(data=mpg, x='cty', y='hwy')
# Out:
# <AxesSubplot:xlabel='cty', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='cty', y='hwy', hue='drv')
# Out:
# <AxesSubplot:xlabel='cty', ylabel='hwy'>

# %%
midwest = pd.read_csv('midwest.csv')

sns.scatterplot(data = midwest, x = 'poptotal', y = 'popasian')\
    .set(xlim = (0, 500000), ylim=(0, 10000))
# Out:
# [(0.0, 500000.0), (0.0, 10000.0)]

# %% [markdown]
# # Lab 3 : 평균 막대 그래프 만들기

# %%
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df_mpg = mpg.groupby('drv', as_index=False).agg(mean_hwy = ('hwy', 'mean'))
df_mpg
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
sns.barplot(data=df_mpg, x='drv', y='mean_hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='mean_hwy'>

# %%
df_mpg
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
df_mpg = df_mpg.sort_values('mean_hwy', ascending = False)
df_mpg
# Out:
#   drv   mean_hwy
# 1   f  28.160377
# 2   r  21.000000
# 0   4  19.174757

# %%
sns.barplot(data=df_mpg, x='drv', y='mean_hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='mean_hwy'>

# %% [markdown]
# # Lab 4 : 빈도 막대 그래프 만들기

# %%
df_mpg = mpg.groupby('drv', as_index=False).agg(count_drv=('drv', 'count'))
df_mpg
# Out:
#   drv  count_drv
# 0   4        103
# 1   f        106
# 2   r         25

# %%
sns.barplot(data=df_mpg, x='drv', y='count_drv')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count_drv'>

# %%
sns.countplot(data=mpg, x='drv')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
sns.countplot(data=mpg, x='drv', order = ['4', 'f', 'r'])
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
sns.countplot(data=mpg, x='drv', order = mpg['drv'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %% [markdown]
# # Lab 5 : 혼자서 해보기 (mpg 데이터 분석)

# %%
mpg.head(3)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact

# %%
mpg.query('category=="suv"').head(3)
# Out:
#    manufacturer               model  displ  year  cyl     trans drv  cty  hwy  \
# 18    chevrolet  c1500 suburban 2wd    5.3  2008    8  auto(l4)   r   14   20
# 19    chevrolet  c1500 suburban 2wd    5.3  2008    8  auto(l4)   r   11   15
# 20    chevrolet  c1500 suburban 2wd    5.3  2008    8  auto(l4)   r   14   20
#
#    fl category
# 18  r      suv
# 19  e      suv
# 20  r      suv

# %%
mpg.query('category=="suv"')\
    .groupby('category', as_index=False)\
    .agg(mean_cty = ('cty', 'mean'))
# Out:
#   category  mean_cty
# 0      suv      13.5

# %%
mpg.query('category=="suv"')
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 18     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# ..           ...                     ...    ...   ...  ...         ...  ..
# 176       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 177       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 198       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 199       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
#
#      cty  hwy fl category
# 18    14   20  r      suv
# 19    11   15  e      suv
# 20    14   20  r      suv
# 21    13   17  r      suv
# 22    12   17  r      suv
# ..   ...  ... ..      ...
# 176   15   17  r      suv
# 177   16   20  r      suv
# 178   14   17  r      suv
# 198   11   15  r      suv
# 199   13   18  r      suv
#
# [62 rows x 11 columns]

# %%
mpg.query('category=="suv"')\
    .groupby('manufacturer', as_index=False)\
    .agg(mean_cty = ('cty', 'mean'))\
    .sort_values('mean_cty', ascending=False)\
    .head()
# Out:
#   manufacturer   mean_cty
# 8       subaru  18.833333
# 9       toyota  14.375000
# 7       nissan  13.750000
# 3         jeep  13.500000
# 6      mercury  13.250000

# %%
df = mpg.query('category=="suv"')\
    .groupby('manufacturer', as_index=False)\
    .agg(mean_cty = ('cty', 'mean'))\
    .sort_values('mean_cty', ascending=False)

# %%
sns.barplot(data=df, x='mean_cty', y='manufacturer')
# Out:
# <AxesSubplot:xlabel='mean_cty', ylabel='manufacturer'>

# %%
df = mpg.groupby('category', as_index=False)\
        .agg(n = ('category', 'count'))\
        .sort_values('n', ascending=False)

# %%
sns.barplot(data=df, x='category', y='n')
# Out:
# <AxesSubplot:xlabel='category', ylabel='n'>

# %% [markdown]
# # Lab 6 : 시계열 그래프 만들기 -  economics 데이터 분석

# %%
import pandas as pd
economics = pd.read_csv('economics.csv')
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 27.0+ KB

# %%
sns.lineplot(data = economics, x='date', y='unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %%
economics['date2'] = pd.to_datetime(economics['date'])

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   data2     574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
economics[['date', 'date2']].head()
# Out:
#          date      date2
# 0  1967-07-01 1967-07-01
# 1  1967-08-01 1967-08-01
# 2  1967-09-01 1967-09-01
# 3  1967-10-01 1967-10-01
# 4  1967-11-01 1967-11-01

# %%
economics['date2'].dt.year
# Out:
# 0      1967
# 1      1967
# 2      1967
# 3      1967
# 4      1967
#        ...
# 569    2014
# 570    2015
# 571    2015
# 572    2015
# 573    2015
# Name: date2, Length: 574, dtype: int64

# %%
economics['date2'].dt.month
# Out:
# 0       7
# 1       8
# 2       9
# 3      10
# 4      11
#        ..
# 569    12
# 570     1
# 571     2
# 572     3
# 573     4
# Name: date2, Length: 574, dtype: int64

# %%
economics['date2'].dt.day
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 569    1
# 570    1
# 571    1
# 572    1
# 573    1
# Name: date2, Length: 574, dtype: int64

# %%
economics['year'] = economics['date2'].dt.year
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      data2  \
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01
#
#        date2  year
# 0 1967-07-01  1967
# 1 1967-08-01  1967
# 2 1967-09-01  1967
# 3 1967-10-01  1967
# 4 1967-11-01  1967

# %%
economics['month'] = economics['date2'].dt.month
economics.head(20)
# Out:
#           date    pce       pop  psavert  uempmed  unemploy      data2  \
# 0   1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01
# 1   1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01
# 2   1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01
# 3   1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01
# 4   1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01
# 5   1967-12-01  525.1  199657.0     11.8      4.8      3018 1967-12-01
# 6   1968-01-01  530.9  199808.0     11.7      5.1      2878 1968-01-01
# 7   1968-02-01  533.6  199920.0     12.3      4.5      3001 1968-02-01
# 8   1968-03-01  544.3  200056.0     11.7      4.1      2877 1968-03-01
# 9   1968-04-01  544.0  200208.0     12.3      4.6      2709 1968-04-01
# 10  1968-05-01  549.8  200361.0     12.0      4.4      2740 1968-05-01
# 11  1968-06-01  556.3  200536.0     11.7      4.4      2938 1968-06-01
# 12  1968-07-01  563.2  200706.0     10.7      4.5      2883 1968-07-01
# 13  1968-08-01  567.0  200898.0     10.5      4.2      2768 1968-08-01
# 14  1968-09-01  568.2  201095.0     10.6      4.6      2686 1968-09-01
# 15  1968-10-01  571.6  201290.0     10.8      4.8      2689 1968-10-01
# 16  1968-11-01  576.7  201466.0     10.6      4.4      2715 1968-11-01
# 17  1968-12-01  576.5  201621.0     11.1      4.4      2685 1968-12-01
# 18  1969-01-01  583.5  201760.0     10.3      4.4      2718 1969-01-01
# 19  1969-02-01  588.7  201881.0      9.7      4.9      2692 1969-02-01
#
#         date2  year  month
# 0  1967-07-01  1967      7
# 1  1967-08-01  1967      8
# 2  1967-09-01  1967      9
# 3  1967-10-01  1967     10
# 4  1967-11-01  1967     11
# 5  1967-12-01  1967     12
# 6  1968-01-01  1968      1
# 7  1968-02-01  1968      2
# 8  1968-03-01  1968      3
# 9  1968-04-01  1968      4
# 10 1968-05-01  1968      5
# 11 1968-06-01  1968      6
# 12 1968-07-01  1968      7
# 13 1968-08-01  1968      8
# 14 1968-09-01  1968      9
# 15 1968-10-01  1968     10
# 16 1968-11-01  1968     11
# 17 1968-12-01  1968     12
# 18 1969-01-01  1969      1
# 19 1969-02-01  1969      2

# %%
sns.lineplot(data = economics, x='year', y='unemploy')
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data = economics, x='year', y='unemploy', hue='month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %%
sns.lineplot(data = economics, x='year', y='unemploy', ci= None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='unemploy'>

# %% [markdown]
# # Lab 7 : 혼자서 해보기 (economics 데이터 분석 그래프 만들기)

# %%
economics['date2'] = pd.to_datetime(economics['date'])

# %%
economics['year'] = economics['date2'].dt.year

# %%
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      data2  \
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01
#
#        date2  year  month
# 0 1967-07-01  1967      7
# 1 1967-08-01  1967      8
# 2 1967-09-01  1967      9
# 3 1967-10-01  1967     10
# 4 1967-11-01  1967     11

# %%
sns.lineplot(data=economics, x='year', y='psavert', ci=None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='psavert'>

# %%
economics['month'] = economics['date2'].dt.month

# %%
df_2014 = economics.query('year == 2014')

# %%
sns.lineplot(data=df_2014, x='month', y='psavert', ci=None)
# Out:
# <AxesSubplot:xlabel='month', ylabel='psavert'>

# %% [markdown]
# # Lab 8 : 상자 그림 만들기

# %%
sns.boxplot(data=mpg, x='drv', y='hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
df = mpg.query('category in ["compact", "subcompact", "suv"]')
df.value_counts()
# Out:
# manufacturer  model               displ  year  cyl  trans       drv  cty  hwy  fl  category
# honda         civic               1.6    1999  4    auto(l4)    f    24   32   r   subcompact    2
# chevrolet     c1500 suburban 2wd  5.3    2008  8    auto(l4)    r    14   20   r   suv           2
# ford          explorer 4wd        4.0    1999  6    auto(l5)    4    14   17   r   suv           2
# dodge         durango 4wd         4.7    2008  8    auto(l5)    4    13   17   r   suv           2
# subaru        impreza awd         2.5    2008  4    auto(s4)    4    20   27   r   compact       1
#                                                                                                 ..
# ford          mustang             4.6    1999  8    manual(m5)  r    15   22   r   subcompact    1
#                                                     auto(l4)    r    15   21   r   subcompact    1
#                                   4.0    2008  6    manual(m5)  r    17   26   r   subcompact    1
#                                                     auto(l5)    r    16   24   r   subcompact    1
# volkswagen    new beetle          2.5    2008  5    manual(m5)  f    20   28   r   subcompact    1
# Length: 140, dtype: int64

# %%
sns.boxplot(data=df, x='category', y='cty')
# Out:
# <AxesSubplot:xlabel='category', ylabel='cty'>
